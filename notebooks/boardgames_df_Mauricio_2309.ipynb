# %%
import pandas as pd
boardgames_df = pd.read_csv("../data/raw/boardgames_df_raw.csv")

# %%
boardgames_df
# Out:
#       row_id                                    boardgame  release_year  \
# 0          1                            Brass: Birmingham          2018
# 1          2                    Pandemic Legacy: Season 1          2015
# 2          3                                     Ark Nova          2021
# 3          4                                   Gloomhaven          2017
# 4          5            Twilight Imperium: Fourth Edition          2017
# ...      ...                                          ...           ...
# 1995    1996                                    Mangrovia          2014
# 1996    1997  1856: Railroading in Upper Canada from 1856          1995
# 1997    1998                             5-Minute Mystery          2020
# 1998    1999                      The Civil War 1861-1865          1983
# 1999    2000                                     Flatiron          2024
#
#       min_players  max_players  min_playtime  max_playtime  minimum_age  \
# 0               2            4            60           120           14
# 1               2            4            60            60           13
# 2               1            4            90           150           14
# 3               1            4            60           120           14
# 4               3            6           240           480           14
# ...           ...          ...           ...           ...          ...
# 1995            2            5            75            75           10
# 1996            3            6           300           300           14
# 1997            1            6             5            30            8
# 1998            1            2           120          1200           12
# 1999            1            2            45            45           12
#
#       avg_rating  num_ratings  ...  rank_strategy  rank_thematic  rank_family  \
# 0          8.575        53548  ...            1.0            NaN          NaN
# 1          8.512        56071  ...            3.0            1.0          NaN
# 2          8.539        54528  ...            2.0            NaN          NaN
# 3          8.557        65443  ...            4.0            2.0          NaN
# 4          8.572        26686  ...            5.0            4.0          NaN
# ...          ...          ...  ...            ...            ...          ...
# 1995       7.166         1841  ...          997.0            NaN        569.0
# 1996       7.469         1357  ...          953.0            NaN          NaN
# 1997       6.994         2371  ...            NaN            NaN        618.0
# 1998       7.730         1289  ...            NaN            NaN          NaN
# 1999       7.563         1300  ...          983.0            NaN          NaN
#
#       rank_war  rank_customizable  rank_abstract  rank_party  rank_childrens  \
# 0          NaN                NaN            NaN         NaN             NaN
# 1          NaN                NaN            NaN         NaN             NaN
# 2          NaN                NaN            NaN         NaN             NaN
# 3          NaN                NaN            NaN         NaN             NaN
# 4          NaN                NaN            NaN         NaN             NaN
# ...        ...                ...            ...         ...             ...
# 1995       NaN                NaN            NaN         NaN             NaN
# 1996       NaN                NaN            NaN         NaN             NaN
# 1997       NaN                NaN            NaN         NaN             NaN
# 1998      79.0                NaN            NaN         NaN             NaN
# 1999       NaN                NaN            NaN         NaN             NaN
#
#                                                     url  \
# 0     https://boardgamegeek.com/boardgame/224517/bra...
# 1     https://boardgamegeek.com/boardgame/161936/pan...
# 2     https://boardgamegeek.com/boardgame/342942/ark...
# 3     https://boardgamegeek.com/boardgame/174430/glo...
# 4     https://boardgamegeek.com/boardgame/233078/twi...
# ...                                                 ...
# 1995  https://boardgamegeek.com/boardgame/165948/man...
# 1996  https://boardgamegeek.com/boardgame/423/1856-r...
# 1997  https://boardgamegeek.com/boardgame/294514/5-m...
# 1998  https://boardgamegeek.com/boardgame/2081/the-c...
# 1999  https://boardgamegeek.com/boardgame/409693/fla...
#
#                                             description
# 0     Build networks, grow industries, and navigate ...
# 1     Mutating diseases are spreading around the wor...
# 2     Plan and build a modern, scientifically manage...
# 3     Vanquish monsters with strategic cardplay. Ful...
# 4     Build an intergalactic empire through trade, r...
# ...                                                 ...
# 1995   Only a chief knows the best placement for a hut!
# 1996  Fight to keep your Canadian railways afloat ag...
# 1997                  A real-time, co-op, mystery game.
# 1998  ACW strategic simulation with detailed leaders...
# 1999  You will participate in the construction of th...
#
# [2000 rows x 57 columns]

# %%
boardgames_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 57 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   row_id             2000 non-null   int64
#  1   boardgame          2000 non-null   object
#  2   release_year       2000 non-null   int64
#  3   min_players        2000 non-null   int64
#  4   max_players        2000 non-null   int64
#  5   min_playtime       2000 non-null   int64
#  6   max_playtime       2000 non-null   int64
#  7   minimum_age        2000 non-null   int64
#  8   avg_rating         2000 non-null   float64
#  9   num_ratings        2000 non-null   int64
#  10  complexity         2000 non-null   float64
#  11  rank_overall       2000 non-null   int64
#  12  owned              2000 non-null   int64
#  13  wishlisted         2000 non-null   int64
#  14  total_plays        2000 non-null   int64
#  15  fans               2000 non-null   int64
#  16  page_views         2000 non-null   int64
#  17  amazon_price       1118 non-null   float64
#  18  std_deviation      2000 non-null   float64
#  19  comments           2000 non-null   int64
#  20  monthly_plays      2000 non-null   int64
#  21  previously_owned   2000 non-null   int64
#  22  for_trade          2000 non-null   int64
#  23  want_trade         2000 non-null   int64
#  24  rating_1           2000 non-null   int64
#  25  rating_2           2000 non-null   int64
#  26  rating_3           2000 non-null   int64
#  27  rating_4           2000 non-null   int64
#  28  rating_5           2000 non-null   int64
#  29  rating_6           2000 non-null   int64
#  30  rating_7           2000 non-null   int64
#  31  rating_8           2000 non-null   int64
#  32  rating_9           2000 non-null   int64
#  33  rating_10          2000 non-null   int64
#  34  categories         1995 non-null   object
#  35  mechanics          1997 non-null   object
#  36  families           1989 non-null   object
#  37  designers          1997 non-null   object
#  38  artists            1941 non-null   object
#  39  publishers         2000 non-null   object
#  40  solo_designers     163 non-null    object
#  41  developers         532 non-null    object
#  42  graphic_designers  643 non-null    object
#  43  sculptors          118 non-null    object
#  44  editors            335 non-null    object
#  45  writers            156 non-null    object
#  46  insert_designers   99 non-null     object
#  47  rank_strategy      1016 non-null   float64
#  48  rank_thematic      393 non-null    float64
#  49  rank_family        614 non-null    float64
#  50  rank_war           130 non-null    float64
#  51  rank_customizable  49 non-null     float64
#  52  rank_abstract      78 non-null     float64
#  53  rank_party         113 non-null    float64
#  54  rank_childrens     17 non-null     float64
#  55  url                2000 non-null   object
#  56  description        2000 non-null   object
# dtypes: float64(12), int64(29), object(16)
# memory usage: 890.8+ KB

# %%
boardgames_df = boardgames_df.drop(columns=["release_year", "rank_overall", "owned", "fans", "page_views", "std_deviation",	"comments", "monthly_plays", "previously_owned", "for_trade", "want_trade", "rating_1", "rating_2", "rating_3", "rating_4", "rating_5", "rating_6", "rating_7", "rating_8", "rating_9", "rating_10", "mechanics", "families", "designers", "artists", "publishers", "solo_designers", "developers", "graphic_designers", "sculptors", "editors", "writers", "insert_designers", "rank_strategy", "rank_thematic", "rank_family", "rank_war", "rank_customizable", "rank_abstract", "rank_party", "rank_childrens"])
boardgames_df
# Out:
#       row_id                                    boardgame  min_players  \
# 0          1                            Brass: Birmingham            2
# 1          2                    Pandemic Legacy: Season 1            2
# 2          3                                     Ark Nova            1
# 3          4                                   Gloomhaven            1
# 4          5            Twilight Imperium: Fourth Edition            3
# ...      ...                                          ...          ...
# 1995    1996                                    Mangrovia            2
# 1996    1997  1856: Railroading in Upper Canada from 1856            3
# 1997    1998                             5-Minute Mystery            1
# 1998    1999                      The Civil War 1861-1865            1
# 1999    2000                                     Flatiron            1
#
#       max_players  min_playtime  max_playtime  minimum_age  avg_rating  \
# 0               4            60           120           14       8.575
# 1               4            60            60           13       8.512
# 2               4            90           150           14       8.539
# 3               4            60           120           14       8.557
# 4               6           240           480           14       8.572
# ...           ...           ...           ...          ...         ...
# 1995            5            75            75           10       7.166
# 1996            6           300           300           14       7.469
# 1997            6             5            30            8       6.994
# 1998            2           120          1200           12       7.730
# 1999            2            45            45           12       7.563
#
#       num_ratings  complexity  wishlisted  total_plays  amazon_price  \
# 0           53548        3.87       20334       152594         69.95
# 1           56071        2.83       14478       301410         76.97
# 2           54528        3.79       16121       528979         71.81
# 3           65443        3.92       21597       542336           NaN
# 4           26686        4.34       12449        49484        172.29
# ...           ...         ...         ...          ...           ...
# 1995         1841        2.44         568         4542           NaN
# 1996         1357        4.25         284         3069           NaN
# 1997         2371        1.17         985        14956           NaN
# 1998         1289        3.79         273          805           NaN
# 1999         1300        2.61         990         4458         36.81
#
#                                              categories  \
# 0     Age of Reason; Economic; Industry / Manufactur...
# 1                                Environmental; Medical
# 2           Animals; Card Game; Economic; Environmental
# 3     Adventure; Exploration; Fantasy; Fighting; Min...
# 4     Civilization; Economic; Exploration; Negotiati...
# ...                                                 ...
# 1995                                                NaN
# 1996                                   Economic; Trains
# 1997                       Murder / Mystery; Party Game
# 1998  American Civil War; Civil War; Post-Napoleonic...
# 1999                                      City Building
#
#                                                     url  \
# 0     https://boardgamegeek.com/boardgame/224517/bra...
# 1     https://boardgamegeek.com/boardgame/161936/pan...
# 2     https://boardgamegeek.com/boardgame/342942/ark...
# 3     https://boardgamegeek.com/boardgame/174430/glo...
# 4     https://boardgamegeek.com/boardgame/233078/twi...
# ...                                                 ...
# 1995  https://boardgamegeek.com/boardgame/165948/man...
# 1996  https://boardgamegeek.com/boardgame/423/1856-r...
# 1997  https://boardgamegeek.com/boardgame/294514/5-m...
# 1998  https://boardgamegeek.com/boardgame/2081/the-c...
# 1999  https://boardgamegeek.com/boardgame/409693/fla...
#
#                                             description
# 0     Build networks, grow industries, and navigate ...
# 1     Mutating diseases are spreading around the wor...
# 2     Plan and build a modern, scientifically manage...
# 3     Vanquish monsters with strategic cardplay. Ful...
# 4     Build an intergalactic empire through trade, r...
# ...                                                 ...
# 1995   Only a chief knows the best placement for a hut!
# 1996  Fight to keep your Canadian railways afloat ag...
# 1997                  A real-time, co-op, mystery game.
# 1998  ACW strategic simulation with detailed leaders...
# 1999  You will participate in the construction of th...
#
# [2000 rows x 16 columns]

# %%
boardgames_df.to_csv("../data/clean/boardgames_df_cleaned.csv", index=False)

# %%
def recommendation_boardgames(boardgames_df):
    # Get user preferences and convert to integers
    playtime = int(input('Please enter the number of minutes you wish to play: '))
    number_players = int(input('Please enter the number of players: '))
    min_age = int(input('Please enter the age of the youngest player: '))
    complexity = float(int(input('Please enter the difficulty level you wish for the game from 1 to 4 (1 - Easy; 2 - Medium; 3 - Hard; 4 - Very Hard): ')))

    # Filter the dataframe using conditions
    filtered_df = boardgames_df[
        (boardgames_df['min_playtime'] <= playtime) &
        (boardgames_df['max_playtime'] <= playtime) &
        (boardgames_df['min_players'] <= number_players) &
        (boardgames_df['max_players'] >= number_players) &
        (boardgames_df['minimum_age'] <= min_age) &
        (boardgames_df['complexity'] <= complexity+1) &
        (boardgames_df['complexity'] >= complexity)
    ]

    filtered_df_ranked = filtered_df.sort_values(by="avg_rating", ascending=False, inplace=False)

    result = filtered_df_ranked.head(5)
    
    return result

# %%
recommendation_boardgames(boardgames_df)
# Out:
# Please enter the number of minutes you wish to play:  150
# Please enter the number of players:  3
# Please enter the age of the youngest player:  12
# Please enter the difficulty level you wish for the game from 1 to 4 (1 - Easy; 2 - Medium; 3 - Hard; 4 - Very Hard):  3
#       row_id                            boardgame  min_players  max_players  \
# 1458    1459                             Agemonia            1            4
# 88        89     Great Western Trail: New Zealand            1            4
# 6          7                    Terraforming Mars            1            5
# 31        32                       Too Many Bones            1            4
# 26        27  Great Western Trail: Second Edition            1            4
#
#       min_playtime  max_playtime  minimum_age  avg_rating  num_ratings  \
# 1458            60           120           10       8.945         1121
# 88              75           150           12       8.501         5701
# 6              120           120           12       8.347       107994
# 31              60           120           12       8.316        15886
# 26              75           150           12       8.284        16100
#
#       complexity  wishlisted  total_plays  amazon_price  \
# 1458        3.32        2415         6991        492.06
# 88          4.00        2262        17510         59.99
# 6           3.27       25730       740148         79.99
# 31          3.87       12583        80318        154.80
# 26          3.71        4971        59591         65.99
#
#                                              categories  \
# 1458                    Adventure; Exploration; Fantasy
# 88                                    Animals; Economic
# 6     Civilization; Economic; Environmental; Industr...
# 31                   Adventure; Dice; Fantasy; Fighting
# 26                     American West; Animals; Economic
#
#                                                     url  \
# 1458  https://boardgamegeek.com/boardgame/270871/age...
# 88    https://boardgamegeek.com/boardgame/380607/gre...
# 6     https://boardgamegeek.com/boardgame/167791/ter...
# 31    https://boardgamegeek.com/boardgame/192135/too...
# 26    https://boardgamegeek.com/boardgame/341169/gre...
#
#                                             description
# 1458  Live your destiny as a mighty hero or despicab...
# 88    Tend to your sheep on the South Island of New ...
# 6     Compete with rival CEOs to make Mars habitable...
# 31    Toss gobs of unique dice in an epic adventure ...
# 26    Wrangle your herd of cows across the Midwest p...

# %%
import streamlit as st
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import streamlit as st
#
# ModuleNotFoundError: No module named 'streamlit'
